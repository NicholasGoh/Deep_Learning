# %% [markdown]
# Dataset taken from [here](https://www.robots.ox.ac.uk/~vgg/data/hands/)

# %%
from utils.visualization import mat, yolo
from utils.mat2yolo import convert

# %% [markdown]
# - Peak at some of the images in `.mat`
# - Convert to `.yolo`
# - Not all hands are labelled but its okay for now

# %%
train_path = '/home/nic/data/hand_dataset/training_dataset/training_data/annotations'
mat(train_path, figsize=(10, 10), skip=10)
convert(train_path)
# Out:
# 4069it [00:31, 127.89it/s]

# %%
test_path = '/home/nic/data/hand_dataset/test_dataset/test_data/annotations'
mat(test_path, figsize=(10, 10), skip=10)
convert(test_path)
# Out:
# 821it [00:05, 145.80it/s]

# %% [markdown]
# Verify correct conversion

# %%
yolo(train_path.replace('annotations', 'yolo'), figsize=(10, 10), skip=10)

# %%
yolo(test_path.replace('annotations', 'yolo'), figsize=(10, 10), skip=10)
