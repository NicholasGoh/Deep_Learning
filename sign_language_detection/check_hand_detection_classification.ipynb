# %%
import os
from utils import detection

# %%
hand_detector_path = '/home/nic/repos/darknet/backup/ssl/ssl-yolov3_best.weights'
hand_detector = detection.load_model(hand_detector_path, weights=True)
classifier_path = './results/classification/model/model_0.h5'
classifier = detection.load_model(classifier_path)
files = os.listdir('/home/nic/data/imgs')
files = [os.path.join('/home/nic/data/imgs', file) for file in files][:5]
save_dir = './results/detection'
# Out:
# model loaded!...
# model loaded!...

# %% [markdown]
# - Hmm predictions seem to be very off, although training with mnist yielded pretty good results
# - Could be due to this test data being very different from the simple mnist training data
# - Perhaps retrain classifier but with data more similar to the test data

# %%
detection.draw_boxes(hand_detector,
                     files,
                     figsize=(10, 10),
                     save_dir=save_dir,
                     classifier=classifier)
